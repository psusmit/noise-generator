# %%
# !pip install tensorflow==2.0.0-alpha0
import tensorflow as tf
tf.__version__
# Out:
# ...
#      |████████████████████████████████| 79.9MB 51.7MB/s
# ...
#      |████████████████████████████████| 3.0MB 14.5MB/s
# ...
#      |████████████████████████████████| 419kB 44.4MB/s
# ...
#   Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# ...
# '2.0.0-alpha0'

# %%
im = cv2.imread("/content/mia0.jpg")
type(im)
# Out:
# numpy.ndarray

# %%
mia = tf.convert_to_tensor(im)
mia

# %%
import random
random.seed( 30 )
n = random.randint(0,500)
a = np.random.randint(n, size=(168, 300, 3))
a = tf.convert_to_tensor(a)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
a = tf.Variable(a,)
mia = tf.Variable(mia,)
mia = tf.cast(mia, tf.int64)
answer = mia*a
answer = answer.numpy()
type(answer)
# Out:
# numpy.ndarray

# %%
from PIL import Image
# %matplotlib inline
img = Image.fromarray(answer, 'RGB')
img.save('/content//my.png')
img.show()

# %%
from IPython.display import Image
Image(filename='/content/my.png')

# %%
from IPython.display import Image
Image(filename='/content/mia0.jpg')

# %%
list=[]
for i in range(100):
  n = random.randint(0,500)
  a = np.random.randint(n, size=(168, 300, 3))
  a = tf.convert_to_tensor(a)
  a = tf.Variable(a,)
  a = a.numpy()
  list.append(a)

# %%
from PIL import Image
for j in range(100):
  img = Image.fromarray(list[j], 'RGB')
  img.save('/content/my{}.png'.format(j))
  # %matplotlib inline
  img.show()

# %%
from IPython.display import Image
Image(filename='/content/my5.png')
